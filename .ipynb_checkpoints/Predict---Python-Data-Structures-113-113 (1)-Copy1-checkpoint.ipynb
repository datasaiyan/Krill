# %% [markdown]
# # Predict - Python Data Structures

# %% [markdown]
# This is the project on Python Data Structures. We will start by transforming the raw data for you. You then need to create 9 functions as specified in the project instructions.
#
# NB: Make sure the football_players.csv file is in the same directory as this notebook
#
# **PROJECT RULES**:
#
# * You may not import any external packages (except for pandas) - all of the functions need to be solved WITHOUT THE USE OF ANY OTHER EXTERNAL MODULES.
# * Most importantly: your functions need to return the answer (not just print it out).
# * Do not add or remove any cells from this notebook. Use another notebook to experiment in (or in which to do your workings), but your submission may not have any additional cells or functions.
# * Only fill in code where the #YOUR CODE tags appear. No code outside these areas (or outside the given functions) will be marked.

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Import Data

# %%
import pandas as pd

# Load data - pass 'Name' as our index column
load_df = pd.read_csv('football_players.csv', index_col='Name').sample(frac=1)

# Create dataframe called df
df = pd.DataFrame(load_df)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Create Position Type Column

# %%
def position_type(s):
    
    """This function converts the individual positions (abbreviations) and classfies it
    as either a forward, midfielder, back or goal keeper"""
    
    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# Create position type column
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# %% [markdown]
# ### Transform Attribute Columns to Floats

# %%
# Select all attribute columns
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

def to_float(x):    
    "Transforms attribute columns to type float"
    
    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

df[cols] = df[cols].applymap(to_float)

# %%
df
# Out:
#                   Age          Nationality  Overall  Acceleration  Aggression  \
# Name
# Jang Cheol Yong    21       Korea Republic     60.0          74.0        68.0
# D. Mottley-Henry   19              England     53.0          85.0        34.0
# Oh Beom Seok       32       Korea Republic     67.0          69.0        71.0
# E. Lugo            32               Mexico     69.0          67.0        40.0
# B. Garnica         21               Mexico     65.0          77.0        32.0
# L. Ndukwu          18              England     58.0          75.0        45.0
# A. Meier           34              Germany     77.0          34.0        60.0
# M. Villanueva      24            Venezuela     74.0          34.0        77.0
# Mauro Riboas       25               Brazil     72.0          67.0        69.0
# Y. Koide           22                Japan     54.0          51.0        56.0
# R. Willmott        27              England     61.0          82.0        56.0
# G. Escobar         20            Argentina     63.0          75.0        64.0
# M. Müller          23              Germany     68.0          25.0        27.0
# O. Ottesen                32.0     26.0             12.0      69.0    33.0
# B. Sanneh                 71.0     73.0             67.0      86.0    43.0
# F. Santander              74.0     76.0             19.0      80.0    68.0
# M. Lorentzson             21.0     24.0             66.0      19.0    58.0
# M. Djetei                 71.0     58.0             67.0      78.0    37.0
# A. Khagush                71.0     82.0             66.0      63.0    46.0
# E. Ávila                  62.0     54.0             63.0      77.0    27.0
# T. Cottes                 24.0     22.0             11.0      49.0    29.0
# T. Barkhuizen             93.0     78.0             24.0      67.0    62.0
# David Simón               80.0     85.0             71.0      60.0    43.0
#
#                   Volleys  Preferred Positions  Preferred Positions Type
# Name
# Jang Cheol Yong      40.0               LB RB                       Back
# D. Mottley-Henry     36.0                  RM                 Midfielder
# Oh Beom Seok         39.0        CB CM CDM RB                       Back
# E. Lugo              70.0           ST CAM RM                 Midfielder
# B. Garnica           54.0                  RM                 Midfielder
# L. Ndukwu            48.0                  RM                 Midfielder
# A. Meier             83.0           CAM CF ST                    Forward
# M. Villanueva        25.0                  CB                       Back
# Mauro Riboas         76.0                 CAM                 Midfielder
# Y. Koide             15.0                  CB                       Back
# R. Willmott          47.0          RWB LW LWB                       Back
# G. Escobar           29.0                  LB                       Back
# M. Müller             9.0                  GK                 GoalKeeper
# M. Mattsson          35.0                  RM                 Midfielder
# M. Alluci            31.0                  CM                 Midfielder
# K. Metz              35.0                  ST                    Forward
# Miramón              54.0        CM LM RB CAM                 Midfielder
# C. Elliott           37.0                  RB                       Back
# D. Collins           28.0                  CB                       Back
# M. Gakpa             60.0               RM LM                 Midfielder
# W. Patching          39.0                  CM                 Midfielder
# P. Bengtsson         60.0                  LB                       Back
# D. Kuciak            11.0                  GK                 GoalKeeper
# R. Lovett             7.0                  GK                 GoalKeeper
# Y. Martelat          39.0                  CM                 Midfielder
# K. Steppe            11.0                  GK                 GoalKeeper
# E. Lorcado           22.0          CAM CM CDM                 Midfielder
# I. Franjić           57.0                  RB                       Back
# L. Summerfield       50.0                  CM                 Midfielder
# H. Dean              23.0                  CB                       Back
# ...                   ...                  ...                       ...
# M. Pučko             65.0            LM RM ST                    Forward
# P. Sané              60.0                  ST                    Forward
# H. Mojica            56.0                 CAM                 Midfielder
# M. McNulty           14.0                  GK                 GoalKeeper
# C. Hall              47.0                  ST                    Forward
# José Callejón        84.0                  RW                    Forward
# O. Marciano          12.0                  GK                 GoalKeeper
# T. Craig             17.0               CB LB                       Back
# C. Sánchez           43.0           CB CM CDM                 Midfielder
# S. Coates            55.0                  CB                       Back
# J. Cano              27.0                  RB                       Back
# D. Gómez             31.0               LB RB                       Back
# R. Pillot            10.0                  GK                 GoalKeeper
# B. Konaté            31.0              CDM CM                 Midfielder
# Enzo Merques         66.0                  LB                       Back
# L. Romagnoli         66.0           RM LM CAM                 Midfielder
# H. Traoré            32.0           RWB RM RB                       Back
# G. Rulli             16.0                  GK                 GoalKeeper
# Alminho Boas         21.0                  GK                 GoalKeeper
# F. Ali               45.0               CM RM                 Midfielder
# O. Ottesen           10.0                  GK                 GoalKeeper
# B. Sanneh            43.0                  CB                       Back
# F. Santander         67.0                  ST                    Forward
# M. Lorentzson        14.0                  RB                       Back
# M. Djetei            35.0                  CB                       Back
# A. Khagush           18.0           RM RB RWB                       Back
# E. Ávila             25.0                  CB                       Back
# T. Cottes             5.0                  GK                 GoalKeeper
# T. Barkhuizen        42.0            ST RM RW                    Forward
# David Simón          36.0                  RB                       Back
#
# [17981 rows x 39 columns]

# %% [markdown]
# ## Function 1
#
# Build an algorithm that identifies the nth ranked (rank) defender in the world - sorted by 'Overall' then 'Name' (both descending order)
# * Under a certain age (max_age)

# %%
### START FUNCTION 1

def best_defender_1(rank, max_age):
    
    # YOUR CODE HERE
    
    return(df[(df['Preferred Positions Type'] == 'Back') & (df['Age'] <= max_age)].sort_values(['Overall', 'Name'], ascending = False).head(10).index[rank - 1])

    raise NotImplementedError()
    
### END FUNCTION 1

# %%
best_defender_1(10, 35)
# Out:
# 'T. Alderweireld'

# %% [markdown]
# ## Function 2
#
# Build an algorithm that identifies the nth ranked (rank) defender in the world - sorted by 'Overall' then 'Name' (both descending order)
# * Under a certain age (max_age)
# * Has an aggression score below a certain level (max_aggression)
# * Has a stamina score above a certain level (min_stamina)

# %%
### START FUNCTION 2

def best_defender_2(rank, max_age, max_aggression, min_stamina):

    # YOUR CODE HERE
    return(df[(df['Preferred Positions Type'] == 'Back') & (df['Age'] < max_age) & (df['Aggression'] < max_aggression) \
       & (df['Stamina'] > min_stamina)].sort_values(['Overall', 'Name'], ascending = False).head(10).index[rank - 1])
    raise NotImplementedError()

### END FUNCTION

# %%
best_defender_2(10, 30, 80, 60)
# Out:
# 'K. Walker'

# %% [markdown]
# ## Function 3
#
# Build an algorithm that identifies the nth ranked (rank) defender in the world - sorted by 'Overall' then 'Name' (both descending order)
# * Under a certain age
# * Does not play for a certain team (team)

# %%
### START FUNCTION 3

def best_defender_3(rank, max_age, team):
    
    # YOUR CODE HERE
    return(df[(df['Preferred Positions Type'] == 'Back') \
       & (df['Age'] < max_age) & (df['Nationality'] != team)]\
    .sort_values(['Overall','Name'], ascending = [False, False]).index[rank - 1])
    raise NotImplementedError()

### END FUNCTION 3

# %%
best_defender_3(10, 25, 'Argentina')
# Out:
# 'A. Rüdiger'

# %% [markdown]
# ## Function 4
#
# Build an algorithm that identifies the nth ranked (rank) attacker in the world - sorted by 'Overall' then 'Name' (both descending order)
# * With specified attribute (attribute_name) above a threshold (min_attribute_score)

# %%
### START FUNCTION 4

def best_attacker_1(rank, attribute_name, min_attribute_score):
    
    # YOUR CODE HERE
    return(df[(df['Preferred Positions Type'] == 'Forward') & \
              (df[attribute_name] > min_attribute_score)]\
           .sort_values(['Overall','Name'], ascending = [False, False]).index[rank - 1])
    raise NotImplementedError()

### END FUNCTION 4

# %%
best_attacker_1(10, 'Balance', 50)
# Out:
# 'P. Aubameyang'

# %% [markdown]
# ## Function 5
#
# Build an algorithm that identifies the nth ranked (rank) attacker in the world - sorted by 'Overall' then 'Name' (both descending order)
# * With average of specified attributes (attribute_1_name, attribute_2_name) above a threshold (min_attributes_ave)

# %%
### START FUNCTION 5

def best_attacker_2(rank, attribute_1_name, attribute_2_name, min_attributes_ave):
    
    # YOUR CODE HERE
    return(df[(df['Preferred Positions Type'] == 'Forward')\
       & (((df[attribute_1_name] + df[attribute_2_name]) / 2) > \
          min_attributes_ave)].sort_values(['Overall','Name'],\
                                           ascending = [False, False]).index[rank - 1])
    raise NotImplementedError()

### END FUNCTION 5

# %%
best_attacker_2(10, 'Finishing', 'Balance', 80)
# Out:
# 'S. Mané'

# %% [markdown]
# ## Function 6
#
# Build an algorithm that identifies the nth ranked (rank) attacker in the world - sorted by 'Overall' then 'Name' (both descending order)
# * With minimum of specified attributes (attribute_1_name, attribute_2_name) above a threshold (min_attributes_min)

# %%
### START FUNCTION 6

def best_attacker_3(rank, attribute_1_name, attribute_2_name, min_attributes_min):
    
    # YOUR CODE HERE
    return(df[(df['Preferred Positions Type'] == 'Forward')\
       & (((df[attribute_1_name] + df[attribute_2_name]) / 2) > \
          min_attributes_ave)].sort_values(['Overall','Name'],\
                                           ascending = [False, False]).index[rank - 1])
    raise NotImplementedError()
    
### END FUNCTION 6

# %%
best_attacker_3(10, 'Balance', 'Composure', 70)

# %% [markdown]
# ## Function 7
#
# Build an algorithm that identifies the best n (no_defenders) defenders - sorted by 'Overall' then 'Name' (both descending order)
# * From a certain country (country)
# * Under a certain age (max_age)
#
# Your function must return a `list` of `strings`

# %%
### START FUNCTION 7

def best_team_1(country, no_defenders, max_age):
    
    # YOUR CODE HERE
    raise NotImplementedError()
    
### END FUNCTION 7

# %%
best_team_1('England', 3, 30)

# %% [markdown]
# ## Function 8
#
# Build an algorithm that identifies the best n (no_attackers) attackers - sorted by 'Overall' then 'Name' (both descending order)
# * From a certain country (country)
# * With a specified attribute (attribute name) above a threshold (min_attribute_score)
#
# Your function must return a `list` of `strings`

# %%
### START FUNCTION 8

def best_team_2(country, no_attackers, attribute_name, min_attribute_score):
    
    # YOUR CODE HERE
    raise NotImplementedError()
    
### END FUNCTION 8

# %%
best_team_2('England', 3, 'Finishing', 60)

# %% [markdown]
# ## Function 9
#
# Build an algorithm that identifies the best team based on the team structure (no_attackers, no_defenders, no_midfielders, no_goalkeepers) - sorted by 'Overall' then 'Name' (both descending order)
# * From a certain country (country)
#
# Your function must return a `list` of `strings`

# %%
### START FUNCTION 9

def best_team_3(country, no_attackers, no_defenders, no_midfielders, no_goalkeepers):
    
    # YOUR CODE HERE
    raise NotImplementedError()
    
### END FUNCTION 9

# %%
best_team_3('England', 3, 4, 3, 1)
